# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# # `SYB65_145_202209_Land.csv`

# %%
data = pd.read_csv('data/raw/SYB65_145_202209_Land.csv')
data.columns = ['region_country_area', 'land', 'year', 'metric_type', 'value', 'footnotes', 'source']

data = data.drop(data.index[0])

print(f"Shape is: {data.shape}")
data.head()
# Out:
# Shape is: (6285, 7)
#   region_country_area                           land  year  \
# 1                   1  Total, all countries or areas  2005
# 2                   1  Total, all countries or areas  2005
# 3                   1  Total, all countries or areas  2005
# 4                   1  Total, all countries or areas  2005
# 5                   1  Total, all countries or areas  2005
#
#                            metric_type       value footnotes  \
# 1        Land area (thousand hectares)  13,020,109       NaN
# 2      Arable land (thousand hectares)   1,366,253       NaN
# 3  Permanent crops (thousand hectares)     145,136       NaN
# 4     Forest cover (thousand hectares)   4,132,183       NaN
# 5   Arable land (% of total land area)        10.5       NaN
#
#                                               source
# 1  Food and Agriculture Organization of the Unite...
# 2  Food and Agriculture Organization of the Unite...
# 3  Food and Agriculture Organization of the Unite...
# 4  Food and Agriculture Organization of the Unite...
# 5  Food and Agriculture Organization of the Unite...

# %%
data.drop(['region_country_area', 'footnotes', 'source'], axis=1, inplace=True)

print(f"Shape is: {data.shape}")
data.head()
# Out:
# Shape is: (6285, 4)
#                             land  year                          metric_type  \
# 1  Total, all countries or areas  2005        Land area (thousand hectares)
# 2  Total, all countries or areas  2005      Arable land (thousand hectares)
# 3  Total, all countries or areas  2005  Permanent crops (thousand hectares)
# 4  Total, all countries or areas  2005     Forest cover (thousand hectares)
# 5  Total, all countries or areas  2005   Arable land (% of total land area)
#
#         value
# 1  13,020,109
# 2   1,366,253
# 3     145,136
# 4   4,132,183
# 5        10.5

# %%
data['value'] = data['value'].str.replace(',', '').astype(float)
data.head()
# Out:
#                             land  year                          metric_type  \
# 1  Total, all countries or areas  2005        Land area (thousand hectares)
# 2  Total, all countries or areas  2005      Arable land (thousand hectares)
# 3  Total, all countries or areas  2005  Permanent crops (thousand hectares)
# 4  Total, all countries or areas  2005     Forest cover (thousand hectares)
# 5  Total, all countries or areas  2005   Arable land (% of total land area)
#
#         value
# 1  13020109.0
# 2   1366253.0
# 3    145136.0
# 4   4132183.0
# 5        10.5

# %% [markdown]
# # `Add country_code found in other files`

# %%
data2 = pd.read_csv('data/cleaned/forest-area-km.csv')

print(f"Shape is: {data2.shape}")
data2.head()
# Out:
# Shape is: (7846, 4)
#         Entity Code  Year  Forest area
# 0  Afghanistan  AFG  1990    1208440.0
# 1  Afghanistan  AFG  1991    1208440.0
# 2  Afghanistan  AFG  1992    1208440.0
# 3  Afghanistan  AFG  1993    1208440.0
# 4  Afghanistan  AFG  1994    1208440.0

# %%
data2 = data2[data2['Code'].isna() == False]

# %%
unique_entities = data2['Entity'].unique()
unique_country_codes = data2['Code'].unique()

country_with_code_list = [(country, country_code) for country, country_code in zip(unique_entities, unique_country_codes)]
len(country_with_code_list)
# Out:
# 224

# %%
unique_lands = data['land'].unique()
len(unique_lands)
# Out:
# 279

# %%
# convert the array of tuples into a dataframe
countries_df = pd.DataFrame(country_with_code_list, columns=["country_name", "country_code"])
countries_df.head()
# Out:
#      country_name country_code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
# merge the two dataframes based on "land" column in df and "country_name" column in countries_df, using left merge
data = pd.merge(data, countries_df, left_on="land", right_on="country_name", how="left")

data.drop('country_name', axis=1, inplace=True)

data.head()
# Out:
#                             land  year                          metric_type  \
# 0  Total, all countries or areas  2005        Land area (thousand hectares)
# 1  Total, all countries or areas  2005      Arable land (thousand hectares)
# 2  Total, all countries or areas  2005  Permanent crops (thousand hectares)
# 3  Total, all countries or areas  2005     Forest cover (thousand hectares)
# 4  Total, all countries or areas  2005   Arable land (% of total land area)
#
#         value country_code
# 0  13020109.0          NaN
# 1   1366253.0          NaN
# 2    145136.0          NaN
# 3   4132183.0          NaN
# 4        10.5          NaN

# %%
countries = ['Viet Nam', 'Venezuela (Boliv. Rep. of)', 'Bolivia (Plurin. State of)', 'Brunei Darussalam', 
             'Cabo Verde', 'China, Hong Kong SAR', 'China, Macao SAR', 'Dem. People\'s Rep. Korea', 
             'Dem. Rep. of the Congo', 'Falkland Islands (Malvinas)', 'French Guiana', 'Iran (Islamic Republic of)', 
             'Polynesia', 'Bonaire, St. Eustatius & Saba', 'Côte d’Ivoire', 'Russian Federation', 
             'United Rep. of Tanzania', 'United States of America']
codes = ['VNM', 'VEN', 'BOL', 'BRN', 
         'CPV', 'CHN', 'CHN', 'PRK', 
         'COD', 'FLK', 'GUF', 'IRN', 
         'PYF', 'BES', 'CIV', 'RUS', 
         'TZA', 'USA']


manual_countries_df = pd.DataFrame({
    'country' : countries,
    'code': codes
})

# merge the two dataframes based on "land" column in df and "country_name" column in countries_df, using left merge
data = pd.merge(data, manual_countries_df, left_on="land", right_on="country", how="left")

data.drop('country', axis=1, inplace=True)

data.head()
# Out:
#                             land  year                          metric_type  \
# 0  Total, all countries or areas  2005        Land area (thousand hectares)
# 1  Total, all countries or areas  2005      Arable land (thousand hectares)
# 2  Total, all countries or areas  2005  Permanent crops (thousand hectares)
# 3  Total, all countries or areas  2005     Forest cover (thousand hectares)
# 4  Total, all countries or areas  2005   Arable land (% of total land area)
#
#         value country_code code
# 0  13020109.0          NaN  NaN
# 1   1366253.0          NaN  NaN
# 2    145136.0          NaN  NaN
# 3   4132183.0          NaN  NaN
# 4        10.5          NaN  NaN

# %%
data['country_code'].fillna(data['code'], inplace=True)
data.drop('code', axis=1, inplace=True)

# %%
data.to_csv('data/cleaned/SYB65_145_202209_Land.csv', index=False)
